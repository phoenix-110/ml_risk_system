# %%
import sys
from pathlib import Path
sys.path.append(str(Path("..").resolve()))

import pandas as pd

# %%
data = pd.read_csv(
    "../data/processed/ml_dataset.csv",
    index_col=0,
    parse_dates=True
)

data.head()
# Out:
#               vol_20    vol_60   vol_120  vol_ratio_20_60  vol_ratio_60_120  \
# Date
# 2015-06-25  0.113112  0.167518  0.193649         0.675226          0.865059
# 2015-06-26  0.110510  0.167839  0.191536         0.658427          0.876276
# 2015-06-29  0.129978  0.174094  0.193719         0.746599          0.898693
# 2015-06-30  0.131448  0.171461  0.192855         0.766636          0.889070
# 2015-07-01  0.135626  0.171956  0.189520         0.788728          0.907322
#
#              skew_60  drawdown  risk_label
# Date
# 2015-06-25  0.858472 -0.013939           0
# 2015-06-26  0.855908 -0.017401           0
# 2015-06-29  0.656272 -0.038343           0
# 2015-06-30  0.723492 -0.036280           0
# 2015-07-01  0.680808 -0.028605           0

# %%
X = data.drop(columns=["risk_label"])
y = data["risk_label"]

print(X.shape)
y.shape
# Out:
# (2395, 7)
# (2395,)

# %%
from src.models import train_risk_model

model = train_risk_model(X, y)
# Out:
# 1676
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90       625
#            1       0.35      0.35      0.35        94
#
#     accuracy                           0.83       719
#    macro avg       0.62      0.63      0.63       719
# weighted avg       0.83      0.83      0.83       719

# %%
import pandas as pd

importance = pd.Series(
    model.feature_importances_,
    index=X.columns
).sort_values(ascending=False)

importance
# Out:
# vol_20              0.227406
# vol_ratio_60_120    0.186085
# vol_60              0.132959
# drawdown            0.117858
# skew_60             0.115753
# vol_120             0.113388
# vol_ratio_20_60     0.106551
# dtype: float64

# %%
from src.models import train_risk_model

model = train_risk_model(X, y)
# Out:
# 1676
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90       625
#            1       0.35      0.35      0.35        94
#
#     accuracy                           0.83       719
#    macro avg       0.62      0.63      0.63       719
# weighted avg       0.83      0.83      0.83       719
