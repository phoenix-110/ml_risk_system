# %%
import sys
from pathlib import Path
sys.path.append(str(Path("..").resolve()))

import pandas as pd
import matplotlib.pyplot as plt
from src.features import build_feature_matrix

# %%
prices = pd.read_csv(
    "../data/raw/prices.csv",
    index_col=0,
    parse_dates=True
)

prices.head()
# Out:
#                  AAPL       MSFT        QQQ         SPY
# Date
# 2015-01-02  24.237553  39.858452  94.784462  170.589615
# 2015-01-05  23.554741  39.491924  93.394058  167.508850
# 2015-01-06  23.556957  38.912292  92.141800  165.931091
# 2015-01-07  23.887280  39.406681  93.329590  167.998764
# 2015-01-08  24.805082  40.565952  95.115929  170.979874

# %%
X = build_feature_matrix(prices)
X.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 X = build_feature_matrix(prices)
#       2 X.head()
#
# File ~/untitled folder/ml_risk_system/src/features.py:41, in build_feature_matrix(prices)
#      39 market_price=prices.mean(axis=1)
#      40 X['drawdown']=drawdown(market_price)
# ---> 41 return X.dropna()
#
# File _pydevd_bundle\\pydevd_cython.pyx:1697, in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# File _pydevd_bundle\\pydevd_cython.pyx:634, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:1368, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:1340, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:494, in _pydevd_bundle.pydevd_cython.PyDBFrame.do_wait_suspend()
#
# ...

# %%
X.to_csv("../data/processed/features.csv")

# %%
X[["vol_20", "vol_60", "vol_120"]].plot(
    figsize=(12,5),
    title="Rolling Volatility Features"
)
plt.show()

# %%
X["drawdown"].plot(
    figsize=(12,4),
    title="Market Drawdown"
)
plt.show()
